# %% [markdown]
# <a href="https://colab.research.google.com/github/fatwa2601/testing_module_1/blob/main/Module_1_Practicum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("anjai praktikum big data 1")
# Out:
# anjai praktikum big data 1
